# %%
import pandas as pd
df = pd.read_csv('example data.csv')

# %%
df
# Out:
#    Participant  Block  Trial  reaction time response
# 0         e001      1      1       1.100716        l
# 1         e001      1      2       0.740111        j
# 2         e001      1      3       0.573494        l
# 3         e001      1      4       0.872830        l
# 4         e001      1      5       0.485087        l
# 5         e001      1      6       0.622876        j
# 6         e001      1      7       0.367862        l
# 7         e001      1      8       0.586826        l
# 8         e001      1      9            NaN     '--'
# 9         e001      1     10       0.868026        j
# 10        e001      2      1       0.701623        l
# 11        e001      2      2       0.600994        l
# 12        e001      2      3       0.901084        l
# 13        e001      2      4       0.817474        l
# 14        e001      2      5       0.517455        l
# 15        e001      2      6       0.600897        l
# 16        e001      2      7       0.700681        l
# ...

# %%
import csv
f = open('example data.csv')
reader= csv.reader(f)
list1 = []
for line in reader: 
    list1.append(line)
print(list1)
# Out:
# [['Participant', 'Block', 'Trial', 'reaction time', 'response'], ['e001', '1', '1', '1.100715931', 'l'], ['e001', '1', '2', '0.740111439', 'j'], ['e001', '1', '3', '0.573494424', 'l'], ['e001', '1', '4', '0.872829995', 'l'], ['e001', '1', '5', '0.485086876', 'l'], ['e001', '1', '6', '0.622875588', 'j'], ['e001', '1', '7', '0.367861597', 'l'], ['e001', '1', '8', '0.586825674', 'l'], ['e001', '1', '9', '', "'--'"], ['e001', '1', '10', '0.868025656', 'j'], ['e001', '2', '1', '0.701623485', 'l'], ['e001', '2', '2', '0.600994397', 'l'], ['e001', '2', '3', '0.901084375', 'l'], ['e001', '2', '4', '0.817473991', 'l'], ['e001', '2', '5', '0.517455377', 'l'], ['e001', '2', '6', '0.600896604', 'l'], ['e001', '2', '7', '0.70068142', 'l'], ['e001', '2', '8', '0.734383159', 'j'], ['e001', '2', '9', '0.634543216', 'j'], ['e001', '2', '10', '0.750579115', 'l'], ['e001', '3', '1', '0.851209335', 'l'], ['e001', '3', '2', '0.870069879', 'j'], ['e001', '3', '3', '0.751343338', 'l'], ['e001', '3', '4', '
# ...

# %%
import csv
import numpy as np
f = open('example data.csv')
reader= csv.reader(f)
e001 = []
e002 = []
e003 = []

for line in reader: 
    if line[0] == 'e001':
        e001.append(line)
    elif line[0] == 'e002':
        e002.append(line)
    elif line[0] == 'e003':
        e002.append(line)

arr_e001 = np.array(e001)
e001_rt = arr_e001[3]
aver_e001= np.mean(e001_rt)
aver_e001
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-f46707678746> in <module>()
#      17 arr_e001 = np.array(e001)
#      18 e001_rt = arr_e001[3]
# ---> 19 aver_e001= np.mean(e001_rt)
#      20 aver_e001
#
# D:\Program Files\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2955
#    2956     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2957                           out=out, **kwargs)
#    2958
#    2959
#
# D:\Program Files\Anaconda\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
import csv
import numpy as np
f = open('example data.csv')
reader= csv.reader(f)
e001 = []
e002 = []
e003 = []

for line in reader: 
    if line[0] == 'e001':
        e001.append(line)
    elif line[0] == 'e002':
        e002.append(line)
    elif line[0] == 'e003':
        e002.append(line)

arr_e001 = np.array(e001)
arr_e001[3].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-28bd79e7ee08> in <module>()
#      16
#      17 arr_e001 = np.array(e001)
# ---> 18 arr_e001[3].mean()
#
# D:\Program Files\Anaconda\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type
